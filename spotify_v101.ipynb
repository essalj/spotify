# %%
# https://developer.spotify.com/web-api/get-playlists-tracks/

# %%
import webbrowser

# %%
import requests
import json

# %%
username='celiche'
password='9558sumirP'

# %%
s = requests.Session()

# %%
def login(username, password):
    response = s.post('https://www.spotify.com/login?',
                      json={'username': username, 'password': password})

    display(response)
    return response

rc=r=login(username='celiche', password='Primus9558')
# Out:
# <Response [200]>

# %%
# def get_auth(username, password):
#     r2=s.get("https://accounts.spotify.com/en/status")
#     r2.content
    
cookies=rc.cookies
display(cookies)


r2=s.get("https://accounts.spotify.com/en/status")
csrf_token=r2.cookies['csrf_token']
display("auth-token: " + csrf_token)
# display(r2.content)
# Out:
# <RequestsCookieJar[Cookie(version=0, name='sp_new', value='1', port=None, port_specified=False, domain='.spotify.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1511076100, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='sp_t', value='dfbafd167f6154a519101c3ee765664a', port=None, port_specified=False, domain='.spotify.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1516173700, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='spot', value='%7B%22t%22%3A1510989570%2C%22m%22%3A%22dk%22%2C%22p%22%3Anull%7D', port=None, port_specified=False, domain='.spotify.com', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1626506500, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='sp_30d', va
# ...

# %%
soup_r2=bs(r2.content)
print(soup_r2.prettify())
# Out:
# <!DOCTYPE html>
# <html ng-app="accounts" ng-csp="">
#  <head>
#   <meta charset="utf-8"/>
#   <title ng-bind="(title &amp;&amp; (title | localize) + ' - ') + 'Spotify'">
#    Spotify
#   </title>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <base href="/"/>
#   <link href="https://d2d1dxiu3v1f2i.cloudfront.net/496c5b7/css/index.css" media="screen" rel="stylesheet"/>
#   <script async="" defer="" sp-bootstrap="" src="https://d2d1dxiu3v1f2i.cloudfront.net/496c5b7/js/index.js">
#   </script>
#   <meta ng-non-bindable="" sp-bootstrap-data='{"country":"DK","locales":["*"],"BON":["0","0",1109696476]}'/>
#  </head>
#  <body ng-view="">
#  </body>
# </html>
# ...

# %%
# playlists

playlists=s.get("https://open.spotify.com/collection/playlists")

# %%
# dir(playlists)

# %%
soup_pl=bs(playlists.content)

# print(soup_pl.prettify())

links=soup_pl.find_all('a')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
for l in links:
    link=l.get('href')
    print(link)
# print(soup_pl)
# soup_pl.find_all('class'="mo-info-name")
# soup_pl.find_all('class'="mo-info-name")
# Out:
# https://www.spotify.com/legal/privacy-policy/#s13
# https://support.spotify.com/using_spotify/the_basics/webplayer
# https://www.spotify.com/download
# /browse
# /user/spotify/playlist/37i9dQZF1DX1s9knjP51Oa
# /user/spotify/playlist/37i9dQZF1DX60OAKjsWlA2
# /user/spotify/playlist/37i9dQZF1DX1xpPUFP8ApA
# /user/spotify/playlist/37i9dQZF1DX7jciJEiGDgb
# /user/spotify/playlist/37i9dQZF1DX09QXWxhgfjP
# /user/spotify/playlist/37i9dQZF1DX9SCu8akzwr1
# /user/spotify/playlist/37i9dQZF1DWWJjgiw92trH
# /user/spotify/playlist/37i9dQZF1DWY4mdqxyphgb
# /view/mood-page
# /view/pop-page
# /view/hiphop-page
# /view/chill-page
# /view/party-page
# /view/holidays-page
# /view/dinner-page
# /view/edm_dance-page
# /browse
# https://www.spotify.com/legal/
# https://www.spotify.com/legal/privacy-policy/
# https://www.spotify.com/legal/privacy-policy/#s13
# https://www.spotify.com/legal/privacy-policy/#s13

# %%
htm_playlist=s.get("https://open.spotify.com/user/celiche/playlist/45PYkjRVIweWL3i5nwjl9G")

# %%
playlist_str=htm_playlist.content

# %%
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup as bs

# %%
soup=bs(playlist_str)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-css3-filters no-focus-outline" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    2017 juni on Spotify
#   </title>
#   <meta name="google" value="notranslate"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="Spotify" property="og:site_name"/>
#   <meta content="174829003346" property="fb:app_id"/>
#   <meta content="A playlist featuring Liam Payne, Charlie Puth, Scarlet Pleasure, and others" property="description"/>
#   <meta content="2017 juni, a playlist by celiche on Spotify" property="og:title"/>
#   <meta content="A playlist featuring Liam Payne, Charlie Puth, Scarlet Pleasure, and others" property="og:description"/>
#   <meta content="https://open.spotify.com/user/celiche/playlist/45PYkjRVIweWL3i5nwjl9G" property="og:url"/>
# ...

# %%
# "https://api.spotify.com/v1/users/spotify_espa%C3%B1a/playlists/21THa8j9TaSGuXYNBU5tsC/tracks

s.get("https://api.spotify.com/v1/users/celiche/playlists/AQBauEx8lrKPlETxfHsuOQJXLnwUoT383OO3AyLcx7oY5RjA__j-Z9WTv1hpM25yEL_rXZFq4da3UPw/tracks")
# Out:
# <Response [401]>

# %%
# r=requests.get("https://www.spotify.com/login?continue=https%3A%2F%2Fwww.spotify.com%2Fdk%2Flogged-in%2F")

# %%
# https://open.spotify.com/browse/featured?_ga=2.90594330.1658194769.1510695784-1345843119.1510695784
# r
# #display(r)

# %%
r2=s.get("https://accounts.spotify.com/en/status")
r2.content
# Out:
# b'<!DOCTYPE html>\n<html ng-app="accounts" ng-csp>\n  <head>\n    <meta charset="utf-8">\n    <title ng-bind="(title && (title | localize) + \' - \') + \'Spotify\'">Spotify</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n    <base href="/">\n    <link href="https://d2d1dxiu3v1f2i.cloudfront.net/496c5b7/css/index.css" media="screen" rel="stylesheet">\n\n    <script async defer src="https://d2d1dxiu3v1f2i.cloudfront.net/496c5b7/js/index.js" sp-bootstrap></script>\n    <meta ng-non-bindable sp-bootstrap-data=\'{"country":"DK","locales":["*"],"BON":["0","0",-357529446]}\'>\n  </head>\n  <body ng-view></body>\n</html>\n'

# %%
import sys
# import spotipy
# import spotipy.util as util

def show_tracks(results):
    for i, item in enumerate(results['items']):
        track = item['track']
        print("   %d %32.32s %s" % (i, track['artists'][0]['name'], track['name']))


# if __name__ == '__main__':
#     if len(sys.argv) > 1:
#         username = sys.argv[1]
#     else:
#         print("Whoops, need your username!")
#         print("usage: python user_playlists_contents.py [username]")
#         sys.exit()

# token = util.prompt_for_user_token(username)
token=csrf_token

if token:
    sp = spotipy.Spotify(auth=token)
    playlists = sp.user_playlists(username)
    for playlist in playlists['items']:
        if playlist['owner']['id'] == username:
            print()
            print(playlist['name'])
            print('  total tracks', playlist['tracks']['total'])
            results = sp.user_playlist(username, playlist['id'], fields="tracks,next")
            tracks = results['tracks']
            show_tracks(tracks)
            while tracks['next']:
                tracks = sp.next(tracks)
                show_tracks(tracks)
else:
print("Can't get token for", username)
# Out:
#   File "<ipython-input-23-177516a57e34>", line 38
#     print("Can't get token for", username)
#         ^
# IndentationError: expected an indented block

# %%
playlist_all=playlist.json
display(playlist_all)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
type(playlist_all)
# Out:
# method

# %%
f=open("tmp_page.html",'w')
f.write(str(playlist_all))
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-57b3e0af2d47> in <module>()
# ----> 1 list(playlist_all)
#       2
#       3 f=open("tmp_page.html",'w')
#       4 f.write(str(playlist_all))
#       5 f.close()
#
# TypeError: 'method' object is not iterable

# %%
ff=open("tmp_page.html",'r')
ff.read()
# Out:
# '<bound method Response.json of <Response [200]>>'

# %%
import webbrowser

url = 'file:///tmp_page.html'
webbrowser.open(url, new=2)  # open in new tab
# Out:
# True

# %%
import json
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup as bs

s = requests.Session()
